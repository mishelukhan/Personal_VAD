# %% [markdown]
# # Train

# %%
from utils import extract_features

path_rttm = "AMITrain/train"
enrolls = extract_features.make_enrolls(path_rttm)
# Out:
# /home/motyashel/miniconda3/envs/pvad/lib/python3.12/site-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# 100%|███████████████████████████████████████████████████████████████████████████████████| 91/91 [00:33<00:00,  2.75it/s]

# %%
from resemblyzer import VoiceEncoder

root = "AMITrain_extracted"
path_corpus = "AMITrain/amicorpus"
embedder = VoiceEncoder()
extract_features.make_trainpart(root, path_corpus, path_rttm, enrolls, embedder, is_debug=False)
# Out:
# Loaded the voice encoder model on cpu in 0.01 seconds.
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15420.24it/s]
# 0it [00:00, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 17549.39it/s]
# 0it [00:00, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11366.68it/s]
# 0it [00:00, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 17050.02it/s]
# 0it [00:00, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14768.68it/s]
# 0it [00:00, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 9000.65it/s]
# 0it [00:00, ?it/s]
# ...

# %%
from IPython.display import Audio as IPythonAudio
import librosa

SAMPLE_RATE = 16000
path = 'AMITrain_extracted/custom_train_pvad/data/train11017/audio.wav'
waveform, _ = librosa.load(path, sr=SAMPLE_RATE)
IPythonAudio(waveform.flatten(), rate=SAMPLE_RATE)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import pandas as pd

path = 'AMITrain_extracted/custom_train_pvad/data/train11017/annot.csv'
df = pd.read_csv(path)

# %%
df.head(64)
# Out:
#                 0
# 0   ['MTD026UID']
# 1   ['MTD026UID']
# 2   ['MTD026UID']
# 3   ['MTD026UID']
# 4   ['MTD026UID']
# ..            ...
# 59  ['MTD026UID']
# 60  ['MTD026UID']
# 61  ['MTD026UID']
# 62  ['MTD026UID']
# 63  ['MTD026UID']
#
# [64 rows x 1 columns]

# %% [markdown]
# # Test

# %%
from utils import extract_features

path_rttm = "AMITest/test"
enrolls = extract_features.make_enrolls(path_rttm)
# Out:
# /home/motyashel/miniconda3/envs/pvad/lib/python3.12/site-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# 100%|███████████████████████████████████████████████████████████████████████████████████| 16/16 [00:06<00:00,  2.58it/s]

# %%
from resemblyzer import VoiceEncoder

root = "AMITest_extracted"
path_corpus = "AMITest/amicorpus"
embedder = VoiceEncoder()
extract_features.make_trainpart(root, path_corpus, path_rttm, enrolls, embedder, is_debug=False, stage='test')
# Out:
# Loaded the voice encoder model on cpu in 0.01 seconds.
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 9962.72it/s]
# 0it [00:00, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 18893.26it/s]
# 0it [00:00, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16980.99it/s]
# 0it [00:00, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16256.99it/s]
# 0it [00:00, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14027.77it/s]
# 0it [00:00, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14820.86it/s]
# 0it [00:00, ?it/s]
# ...

# %%
from IPython.display import Audio as IPythonAudio
import librosa

SAMPLE_RATE = 16000
path = 'AMITest_extracted/custom_test_pvad/data/test2211/audio.wav'
waveform, _ = librosa.load(path, sr=SAMPLE_RATE)
IPythonAudio(waveform.flatten(), rate=SAMPLE_RATE)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import pandas as pd

path = 'AMITest_extracted/custom_test_pvad/data/test2211/annot.csv'
df = pd.read_csv(path)

df.head(64)
# Out:
#              0
# 0   ['MEE071']
# 1   ['MEE071']
# 2   ['MEE071']
# 3   ['MEE071']
# 4   ['MEE071']
# ..         ...
# 59  ['MEE071']
# 60  ['MEE071']
# 61  ['MEE071']
# 62  ['MEE071']
# 63  ['MEE071']
#
# [64 rows x 1 columns]
